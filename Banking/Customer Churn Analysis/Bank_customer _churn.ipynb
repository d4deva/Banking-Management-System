# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"D:\project\banking\Churn_Modelling.csv")

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.shape
# Out:
# (10000, 14)

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
# RowNumber          10000 non-null int64
# CustomerId         10000 non-null int64
# Surname            10000 non-null object
# CreditScore        10000 non-null int64
# Geography          10000 non-null object
# Gender             10000 non-null object
# Age                10000 non-null int64
# Tenure             10000 non-null int64
# Balance            10000 non-null float64
# NumOfProducts      10000 non-null int64
# HasCrCard          10000 non-null int64
# IsActiveMember     10000 non-null int64
# EstimatedSalary    10000 non-null float64
# Exited             10000 non-null int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df1 = df.drop(['RowNumber','Surname','CustomerId'],axis=1)

# %%
print(df1.Gender.unique())
print(df1.Geography.unique())
# Out:
# ['Female' 'Male']
# ['France' 'Spain' 'Germany']

# %%
df1
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
df1 = pd.get_dummies(df1,drop_first=True)
df1
# Out:
#       CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619   42       2       0.00              1          1
# 1             608   41       1   83807.86              1          0
# 2             502   42       8  159660.80              3          1
# 3             699   39       1       0.00              2          0
# 4             850   43       2  125510.82              1          1
# ...           ...  ...     ...        ...            ...        ...
# 9995          771   39       5       0.00              2          1
# 9996          516   35      10   57369.61              1          1
# 9997          709   36       7       0.00              1          0
# 9998          772   42       3   75075.31              2          1
# 9999          792   28       4  130142.79              1          1
#
#       IsActiveMember  EstimatedSalary  Exited  Geography_Germany  \
# 0                  1        101348.88       1                  0
# ...

# %%
plt.figure(figsize=(15,10))
ax = sns.heatmap(df1.corr(),annot=True,cmap='RdYlGn')
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (12.0, 0.0)

# %%
print(df1.NumOfProducts.value_counts())
print(df1.HasCrCard.value_counts())
print(df1.IsActiveMember.value_counts())
print(df1.Exited.value_counts())
# Out:
# 1    5084
# 2    4590
# 3     266
# 4      60
# Name: NumOfProducts, dtype: int64
# 1    7055
# 0    2945
# Name: HasCrCard, dtype: int64
# 1    5151
# 0    4849
# Name: IsActiveMember, dtype: int64
# 0    7963
# 1    2037
# Name: Exited, dtype: int64

# %%
labels=['1 Product','2 Product','3 Product','4 Product']
plt.pie(df1.NumOfProducts.value_counts(),explode=[0.1,0.1,0,0],shadow=True,startangle=45,labels=labels,autopct='%1.0f%%')
plt.show()

# %%
labels=['Have Credit Card','Does not have Credit Card']
plt.pie(df1.HasCrCard.value_counts(),explode=[0.1,0],shadow=True,startangle=45,labels=labels,autopct='%1.0f%%')
plt.show()

# %%
labels=['Is Active Member','Is Not Active Member']
plt.pie(df1.IsActiveMember.value_counts(),explode=[0.1,0],shadow=True,startangle=45,labels=labels,autopct='%1.0f%%')
plt.show()

# %%
labels=['Customer In Present','Customer Churned Out']
plt.pie(df1.Exited.value_counts(),explode=[0.2,0],shadow=True,startangle=45,labels=labels,autopct='%1.0f%%')
plt.show()

# %%
sns.pairplot(df1)
plt.show()

# %%
fig, axes = plt.subplots(4, 3,figsize=(16,8))
sns.boxplot(x=df1.Exited, y=df1.CreditScore,ax=axes[0,0])
sns.boxplot(x=df1.Exited, y=df1.Age,ax=axes[0,1])
sns.boxplot(x=df1.Exited, y=df1.Tenure,ax=axes[0,2])
sns.boxplot(x=df1.Exited, y=df1.Balance,ax=axes[1,0])
sns.boxplot(x=df1.Exited, y=df1.NumOfProducts,ax=axes[1,1])
sns.boxplot(x=df1.Exited, y=df1.HasCrCard,ax=axes[1,2])
sns.boxplot(x=df1.Exited, y=df1.IsActiveMember,ax=axes[2,0])
sns.boxplot(x=df1.Exited, y=df1.EstimatedSalary,ax=axes[2,1])
sns.boxplot(x=df1.Exited, y=df1.Geography_Germany,ax=axes[2,2])
sns.boxplot(x=df1.Exited, y=df1.Geography_Spain,ax=axes[3,0])
sns.boxplot(x=df1.Exited, y=df1.Gender_Male,ax=axes[3,1])
plt.show()

# %%
X = df1.drop('Exited',axis=1)
y = df1.Exited

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=55)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report#, roc_curve, roc_auc_score, auc

# %%
confusion_matrix(y_true=y_test,y_pred=y_pred)
# Out:
# array([[1542,   56],
#        [ 312,   90]], dtype=int64)

# %%
print('Accuracy Score:',accuracy_score(y_test,y_pred)*100,'%')
# Out:
# Accuracy Score: 81.6 %

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.96      0.89      1598
#            1       0.62      0.22      0.33       402
#
#     accuracy                           0.82      2000
#    macro avg       0.72      0.59      0.61      2000
# weighted avg       0.79      0.82      0.78      2000

# %%
lr2=LogisticRegression(class_weight={1:2.4546,0:0.6279})

# %%
lr2.fit(X_train,y_train)
# Out:
# LogisticRegression(class_weight={0: 0.6279, 1: 2.4546})

# %%
y_pred = lr2.predict(X_test)

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1117,  481],
#        [ 107,  295]], dtype=int64)

# %%
print('Accuracy Score:',accuracy_score(y_test,y_pred)*100,'%')
# Out:
# Accuracy Score: 70.6 %

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.70      0.79      1598
#            1       0.38      0.73      0.50       402
#
#     accuracy                           0.71      2000
#    macro avg       0.65      0.72      0.65      2000
# weighted avg       0.81      0.71      0.73      2000

# %% [markdown]
# ## Knn Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
knn.score(X_test,y_test)
# Out:
# 0.8245

# %%
score = {}
for i in range(1,40):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    score[i] = knn.score(X_test, y_test)
print (score)
# Out:
# {1: 0.7855, 2: 0.8235, 3: 0.8165, 4: 0.825, 5: 0.8245, 6: 0.8275, 7: 0.829, 8: 0.8275, 9: 0.8315, 10: 0.832, 11: 0.835, 12: 0.8355, 13: 0.8335, 14: 0.832, 15: 0.8365, 16: 0.8335, 17: 0.8325, 18: 0.8325, 19: 0.8365, 20: 0.836, 21: 0.8395, 22: 0.834, 23: 0.836, 24: 0.8375, 25: 0.839, 26: 0.8355, 27: 0.8375, 28: 0.8355, 29: 0.8365, 30: 0.8355, 31: 0.8365, 32: 0.8345, 33: 0.8355, 34: 0.8325, 35: 0.8335, 36: 0.8325, 37: 0.834, 38: 0.831, 39: 0.833}

# %%
error = {}
for i in range(1, 40):  
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(X_train, y_train)
    pred_i = knn.predict(X_test)
    error[i]=np.mean(pred_i != y_test)
print (error)
# Out:
# {1: 0.2145, 2: 0.1765, 3: 0.1835, 4: 0.175, 5: 0.1755, 6: 0.1725, 7: 0.171, 8: 0.1725, 9: 0.1685, 10: 0.168, 11: 0.165, 12: 0.1645, 13: 0.1665, 14: 0.168, 15: 0.1635, 16: 0.1665, 17: 0.1675, 18: 0.1675, 19: 0.1635, 20: 0.164, 21: 0.1605, 22: 0.166, 23: 0.164, 24: 0.1625, 25: 0.161, 26: 0.1645, 27: 0.1625, 28: 0.1645, 29: 0.1635, 30: 0.1645, 31: 0.1635, 32: 0.1655, 33: 0.1645, 34: 0.1675, 35: 0.1665, 36: 0.1675, 37: 0.166, 38: 0.169, 39: 0.167}

# %%
x = list(score.keys())
y=list(score.values())
plt.figure(figsize = (11, 4))
plt.subplot(1,2,1,)
plt.plot(x, y, color='blue', linestyle='dashed', marker='o',  
         markerfacecolor='red', markersize=8)
plt.xlabel('k')
plt.ylabel('Accuracy')

plt.subplot(1,2,2)
plt.plot(list(error.keys()), list(error.values()), color='red', linestyle='dashed', marker='o',  
         markerfacecolor='blue', markersize=8)
plt.xlabel('k')
plt.ylabel('Error Rate')

plt.show()

# %%
print(max(score, key=score.get), max(score.values()))
print(min(error, key=error.get), min(error.values()))
# Out:
# 21 0.8395
# 21 0.1605

# %%
knn = KNeighborsClassifier(n_neighbors=21)
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=21)

# %%
y_pred1 = knn.predict(X_test)

# %%
confusion_matrix(y_true=y_test,y_pred=y_pred1)
# Out:
# array([[1552,   46],
#        [ 275,  127]], dtype=int64)

# %%
print('Accuracy Score:',accuracy_score(y_test,y_pred1)*100,'%')
# Out:
# Accuracy Score: 83.95 %

# %%
print(classification_report(y_test,y_pred1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.97      0.91      1598
#            1       0.73      0.32      0.44       402
#
#     accuracy                           0.84      2000
#    macro avg       0.79      0.64      0.67      2000
# weighted avg       0.83      0.84      0.81      2000

# %% [markdown]
# ## Model 2: Random Forest Classifier

# %%
X = df1.drop('Exited',axis=1)
y = df1.Exited

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=55)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred2 = rfc.predict(X_test)

# %%
confusion_matrix(y_true=y_test,y_pred=y_pred2)
# Out:
# array([[1514,   84],
#        [ 201,  201]], dtype=int64)

# %%
print('Accuracy Score:',accuracy_score(y_test,y_pred2)*100,'%')
# Out:
# Accuracy Score: 85.75 %

# %%
rfc.feature_importances_
# Out:
# array([0.14387864, 0.23653978, 0.0819145 , 0.1456519 , 0.12696553,
#        0.01837359, 0.03816584, 0.14654852, 0.02942631, 0.01358884,
#        0.01894653])

# %%
fig, ax = plt.subplots(figsize=(10,5))
bar_rects = ax.bar(np.arange(11), rfc.feature_importances_, color='r', align='center')
ax.xaxis.set_ticks(np.arange(11))
ax.set_xticklabels(X.columns, rotation='vertical')
plt.show()

# %%
from sklearn.model_selection import RandomizedSearchCV

# %%
# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)]

# Number of features to consider at every split
max_features = ['auto', 'sqrt']

# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(1, 110, num = 11)]


# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10]

# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 4]

# Method of selecting samples for training each tree
bootstrap = [True, False]

# %%
#Create the random grid
param_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf,
               'bootstrap': bootstrap}

# %%
# Use the random grid to search for best hyperparameters

# First create the base model to tune
rf = RandomForestClassifier()

# Random search of parameters, using 3 fold cross validation, 
# search across 100 different combinations, and use all available cores
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = param_grid, 
                               n_iter = 100, cv = 5, verbose=2, random_state = 10, n_jobs = -1)

# Fit the random search model
rf_random.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 100 candidates, totalling 500 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 146 tasks      | elapsed: 10.7min
# [Parallel(n_jobs=-1)]: Done 349 tasks      | elapsed: 25.5min
# [Parallel(n_jobs=-1)]: Done 500 out of 500 | elapsed: 35.8min finished
# RandomizedSearchCV(cv=5, estimator=RandomForestClassifier(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'max_depth': [1, 11, 22, 33, 44, 55, 66,
#                                                       77, 88, 99, 110],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 4],
#                                         'min_samples_split': [2, 5, 10],
# ...

# %%
rf_random.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_split': 5,
#  'min_samples_leaf': 2,
#  'max_features': 'sqrt',
#  'max_depth': 11,
#  'bootstrap': False}

# %%
# Manually provide the best parameters to model for training
rf_class= RandomForestClassifier(**{'n_estimators': 400,
 'min_samples_split': 5,
 'min_samples_leaf': 2,
 'max_features': 'sqrt',
 'max_depth': 11,
 'bootstrap': False})

# %%
rf_class.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=False, max_depth=11, max_features='sqrt',
#                        min_samples_leaf=2, min_samples_split=5,
#                        n_estimators=400)

# %%
y_pred3 = rf_class.predict(X_test)

# %%
confusion_matrix(y_true=y_test,y_pred=y_pred3)
# Out:
# array([[1535,   63],
#        [ 209,  193]], dtype=int64)

# %%
print('Accuracy Score:',accuracy_score(y_test,y_pred3)*100,'%')
# Out:
# Accuracy Score: 86.4 %

# %%
print(classification_report(y_test,y_pred3))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.96      0.92      1598
#            1       0.75      0.48      0.59       402
#
#     accuracy                           0.86      2000
#    macro avg       0.82      0.72      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %% [markdown]
# ## Model 4: Gradient Boosting Classifier

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV

# %%
param_dist = {'max_features' : ['sqrt', 'log2', 0.5],
              'max_depth' : [6, 7, 8,10],
              'min_samples_leaf' : [8, 10, 12],
              'n_estimators': [int(x) for x in np.linspace(start = 200, stop = 2000, num = 10)],
              'learning_rate' : [0.08, 0.1, 0.15, 0.2],
              'loss' : ['deviance','exponential']
             }

# %%
pre_gb_model = RandomizedSearchCV(GradientBoostingClassifier(warm_start=True),
                                   param_distributions = param_dist,
                                   cv=5,
                                   n_iter = 30, n_jobs=-1)

# %%
pre_gb_model.fit(X_train, y_train)
# Out:
# RandomizedSearchCV(cv=5, estimator=GradientBoostingClassifier(warm_start=True),
#                    n_iter=30, n_jobs=-1,
#                    param_distributions={'learning_rate': [0.08, 0.1, 0.15, 0.2],
#                                         'loss': ['deviance', 'exponential'],
#                                         'max_depth': [6, 7, 8, 10],
#                                         'max_features': ['sqrt', 'log2', 0.5],
#                                         'min_samples_leaf': [8, 10, 12],
#                                         'n_estimators': [200, 400, 600, 800,
#                                                          1000, 1200, 1400, 1600,
#                                                          1800, 2000]})

# %%
pre_gb_model.best_params_
# Out:
# {'n_estimators': 400,
#  'min_samples_leaf': 12,
#  'max_features': 'log2',
#  'max_depth': 7,
#  'loss': 'exponential',
#  'learning_rate': 0.08}

# %%
rs_gbt = GradientBoostingClassifier(warm_start=True,
                                    n_estimators = 400,
                                    min_samples_leaf =12,
                                    max_features = 'log2',
                                    max_depth = 7,
                                    loss = 'exponential',
                                    learning_rate=0.08)

# %%
rs_gbt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(learning_rate=0.08, loss='exponential', max_depth=7,
#                            max_features='log2', min_samples_leaf=12,
#                            n_estimators=400, warm_start=True)

# %%
y_pred4 = pre_gb_model.predict(X_test)
y_pred4_train = pre_gb_model.predict(X_train)

# %%
confusion_matrix(y_true=y_test,y_pred=y_pred4)
# Out:
# array([[1508,   90],
#        [ 195,  207]], dtype=int64)

# %%
print('Accuracy Score:',accuracy_score(y_test,y_pred4)*100,'%')
# Out:
# Accuracy Score: 85.75 %

# %%
print(classification_report(y_test,y_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1598
#            1       0.70      0.51      0.59       402
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.73      0.75      2000
# weighted avg       0.85      0.86      0.85      2000

# %% [markdown]
# ## Model 5: XGBoost Classifier

# %%
from xgboost import XGBClassifier

# %%
model = XGBClassifier()
model.fit(X_train, y_train)

predictions = model.predict(X_test)
# Out:
# [16:59:38] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.3.0/src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.

# %%
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
print(classification_report(y_test,predictions))
# Out:
# Accuracy: 85.75%
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91      1598
#            1       0.69      0.52      0.60       402
#
#     accuracy                           0.86      2000
#    macro avg       0.79      0.73      0.76      2000
# weighted avg       0.85      0.86      0.85      2000
